# %%
import sys
import os

# Go up one level to the project root and add it to the path
sys.path.append(os.path.abspath(os.path.join('/home/selowa-mphadi/PycharmProjects/pythonProject/kmeans clustering/src')))

from src.data.load_data import DataLoader

# Initialize the loader
loader = DataLoader(data_path='data/')

#Load and get the full report immediately
df = loader.load_and_inspect('/home/selowa-mphadi/PycharmProjects/pythonProject/kmeans clustering/raw data/rt_data.csv')
# Out:
# ...
# DATA LOADED: /home/selowa-mphadi/PycharmProjects/pythonProject/kmeans clustering/raw data/rt_data.csv
# ...
#
# --- FIRST 5 ROWS ---
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...
